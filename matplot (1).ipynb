# %%
import matplotlib.pyplot as plt
x=[1,2,3x,4,5]
y=[10,15,7,12,9]
plt.plot(x,y,marker='o')
plt.title("line chart example")
plt.xlabel("time")
plt.ylabel("department variable")
plt.show()

# %%
import matplotlib.pyploti as plt
categories=['category1','category2','category3','category4']
values=[25,40,30,50]
plt.bar(categories,values)
plt.title("BAR PLOT EXAMPLE")
plt.xlabel("catgories")
plt.ylabel("value")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/yash.csv2.csv")
x=list(df['EMPLOYEE_ID'])
y=list(df['SALARY'])
plt.plot(x,y,marker='o')
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
x=list(df['JOB_ID'])
z=df.groupby('JOB_ID')
plt.plot(z,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-2ebcdeb9a8ac> in <cell line: 3>()
#       1 x=list(df['JOB_ID'])
#       2 z=df.groupby('JOB_ID')
# ----> 3 plt.plot(z,y)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
# ...

# %%
import matplotlib.pyplot as plt
x=list(df['SALARY'])
plt.hist(x,bins=5,edgecolor='black')
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,15,7,12,9,12]
plt.scatter(x,y,marker='o')
plt.title("SCATTER PLOT EXAMPLE")
plt.xlabel("time")
plt.ylabel("department variable")
plt.show()

# %%
a=list(df['EMPLOYEE_ID'])
b=list(df['SALARY'])
plt.scatter(a,b,color='black')
plt.title('scatter')
# Out:
# Text(0.5, 1.0, 'scatter')

# %%
import matplotlib.pyplot as plt
categories=['category1','category2','category3','category4']
values=[35,20,15,30]
plt.pie(value,labels=categories,autopct='%1.1f%%')
plt.xlabel("catgories")
plt.ylabel("value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-136be4d58118> in <cell line: 4>()
#       2 categories=['category1','category2','category3','category4']
#       3 values=[35,20,15,30]
# ----> 4 plt.pie(value,labels=categories,autopct='%1.1f%%')
#       5 plt.ylabel("value")
#       6 plt.show()
#
# NameError: name 'value' is not defined

# %%
import matplotlib.pyplot as plt
a=['c1','c2','c3','c4']
b=[10,20,40,30]
plt.pie(b,labels=a,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0c9ead42e0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'c1'),
#   Text(0.33991867422268784, 1.0461621742897658, 'c2'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'c3'),
#   Text(0.6465638691739385, -0.8899186272232008, 'c4')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.0%'),
#   Text(0.1854101859396479, 0.5706339132489631, '20.0%'),
#   Text(-0.5999999999999993, -2.808802703071063e-08, '40.0%'),
#   Text(0.35267120136760277, -0.48541016030356404, '30.0%')])

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')
grid=sns.FacetGrid(titanic,row='class',col='sex')
grid.map(sns.histplot,'age')
grid.set_axis_labels('age','count')
grid.set_titles(row_template='{row_name} class',col_template='{col_name}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-178304976e0d> in <cell line: 7>()
#       5 grid.set_axis_labels('age','count')
#       6 grid.set_titles(row_template='{row_name} class',col_template='{col_name}')
# ----> 7 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y1= np.sin(x)
y2= np.cos(x)
y3= np.tan(x)
flg, axes = plt.subplots(3,1,figsize=(8,10))
axes[0].plot(x,y1, color='red')
axes[0].set_title('plot 1: sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,y2, color='green')
axes[1].set_title('plot 1: cos(x)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')

axes[2].plot(x,y3, color='blue')
axes[2].set_title('plot 1: tan(x)')
saxes[2].set_xlabel('x')
axes[2].set_ylabel('y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-163c9f10f8c3> in <cell line: 20>()
#      18 axes[2].plot(x,y3, color='blue')
#      19 axes[2].set_title('plot 1: tan(x)')
# ---> 20 saxes[2].set_xlabel('x')
#      21 axes[2].set_ylabel('y')
#
# NameError: name 'saxes' is not defined

# %%
import plotly.graph_objects as go
import plotly.subplots as sp
x=[1,2,3,4,5];y1=[1,4,9,16,25];y2=[10,8,6,4,2];y3=[1,8,27,64,125]
fig=sp.make_subplots(rows=1,cols=3,subplot_titles=('panel 1','panel 2','panel3'))
fig.add_trace(go.Scatter(x=x,y=y1,name='Trace 1'),row=1,col=1)
fig.add_trace(go.Scatter(x=x,y=y2,name='Trace 2'),row=1,col=2)
fig.add_trace(go.Scatter(x=x,y=y3,name='Trace 3'),row=1,col=3)
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
